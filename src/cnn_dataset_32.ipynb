# %%
# THIS NOTEBOOK VISUALIZES 32by32 RESOLUTION DATASETS USED TO TRAIN THE CNN AUTOENCODER

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
from data_loader import DataLoader
from utils.visualize import show_images_in_grid

# %%
root = os.getcwd()

# %%
cnn_data_loader = DataLoader()

# %%
cnn_data_loader.X_train = np.reshape(np.load(root+"/../datasets/train/32/X_train.npy"), (-1, 32, 32, 3))
cnn_data_loader.Y_train = np.reshape(np.load(root+"/../datasets/train/32/Y_train.npy"), (-1, 32, 32, 3))
cnn_data_loader.X_val = np.reshape(np.load(root+"/../datasets/val/32/X_val.npy"), (-1, 32, 32, 3))
cnn_data_loader.Y_val = np.reshape(np.load(root+"/../datasets/val/32/Y_val.npy"), (-1, 32, 32, 3))
cnn_data_loader.X_test = np.reshape(np.load(root+"/../datasets/test/32/X_test.npy"), (-1, 32, 32, 3))
cnn_data_loader.Y_test = np.reshape(np.load(root+"/../datasets/test/32/Y_test.npy"), (-1, 32, 32, 3))

# %%
cnn_data_loader.X_train.shape, cnn_data_loader.X_val.shape, cnn_data_loader.X_test.shape
# Out:
# ((80000, 32, 32, 3), (10000, 32, 32, 3), (10000, 32, 32, 3))

# %%
show_images_in_grid(images=cnn_data_loader.X_train, columns=10, rows=5, img_size=(50,50), plot_size=(20,10), rescale=False)
