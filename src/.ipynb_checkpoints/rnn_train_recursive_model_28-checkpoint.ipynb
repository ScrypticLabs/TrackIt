# %%
# THIS NOTEBOOK IS A PRELIMINARY ATTEMPT TO FEED THE NETWORK PREDICTIONS BACK INTO THE NETWORK AS INPUT

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
from data_loader import DataLoader
from utils.visualize import show_images_in_grid, show_images_as_video, show_reconstructions, compare_images_as_video
from cnn import Autoencoder
from rnn import Seq2Seq
import random
# Out:
# Using TensorFlow backend.
# /home/abhi/anaconda3/envs/envTF113/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/abhi/anaconda3/envs/envTF113/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/abhi/anaconda3/envs/envTF113/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/abhi/anaconda3/envs/envTF113/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/abhi/anaconda3/envs/envTF113/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/abhi/anaconda3/envs/envTF113/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
root = os.getcwd()
rnn_train_dir = root+"/../datasets/training_set/data/rnn.npy"
rnn_test_dir = root+"/../datasets/test_set/data/rnn.npy"

# %%
# WE WON'T USE THE TEST DATA AT ALL AND INSTEAD SPLIT THE TRAIN DATA INTO TRAIN, TEST, AND VALIDATION DATASETS WITH THE DATA LOADER

# %%
rnn_data_loader = DataLoader(features_dir=rnn_train_dir, labels_dir=rnn_train_dir)

# %%
rnn_data_loader.split_train_val_test(train=0.7, val=0.2, test=0.1)

# %%
# NORMALIZE ALL PIXEL VALUES FROM 0-255 TO O-1

# %%
rnn_data_loader.preprocess(rescale=True)

# %%
ae = Autoencoder()
ae.build_model(input_dim=(28, 28, 3), latent_dim=(64,))
ae.set_weights(root+"/../models/autoencoder.h5")
# Out:
# WARNING:tensorflow:From /home/abhi/anaconda3/envs/envTF113/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
np.save(root+"/X_train.npy", rnn_data_loader.X_train)
np.save(root+"/X_val.npy", rnn_data_loader.X_val)
np.save(root+"/X_test.npy", rnn_data_loader.X_test)

# %%
X_train = np.load(root+"/X_train.npy")
X_val = np.load(root+"/X_val.npy")
X_test = np.load(root+"/X_test.npy")

# %%
X_train = ae.encode_series(rnn_data_loader.X_train)
X_val = ae.encode_series(rnn_data_loader.X_val)
X_test = ae.encode_series(rnn_data_loader.X_test)

# %%
X_train = ae.encode_series(X_train)
X_val = ae.encode_series(X_val)
X_test = ae.encode_series(X_test)

# %%
X_train.shape
# Out:
# (84, 105, 64)

# %%
seq = Seq2Seq()
seq.build_model(input_length=20, input_dim=64, latent_dim=(256,), output_length=30, output_dim=64)

# %%
seq.set_weights(root+"/../models/seq2seq_recursive_v1.h5")

# %%
seq.encoder.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 20, 64)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 20, 1024)          4460544
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 20, 512)           3147776
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 256)               787456
# =================================================================
# Total params: 8,395,776
# Trainable params: 8,395,776
# Non-trainable params: 0
# _________________________________________________________________

# %%
seq.decoder.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 256)               0
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 30, 256)           0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 30, 512)           1574912
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 30, 1024)          6295552
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 30, 64)            65600
# =================================================================
# Total params: 7,936,064
# Trainable params: 7,936,064
# Non-trainable params: 0
# _________________________________________________________________

# %%
# TRAIN LOOP
X_train_in, Y_train_in = X_train[:, :20, :], X_train[:, 20:20+30, :]
X_val_in, Y_val_in     = X_val[:, :20, :], X_val[:, 20:20+30, :]
T = 2

for epoch in range(10000):
    print('EPOCH %d' % (epoch))
    for t in range(1, T+1):
        print(X_train_in.shape, Y_train_in.shape)
        seq.train(X_train=X_train_in, 
                 Y_train=Y_train_in, 
                 X_val=X_val_in, 
                 Y_val=Y_val_in, 
                 epochs=1, 
                 batch_size=32
                 )
        X_train_in = seq.model.predict(X_train_in)[:,:20,:]
        Y_train_in = X_train[:, (t+1)*20:(t+1)*20+30, :]
        X_val_in = seq.model.predict(X_val_in)[:, :20, :]
        Y_val_in = X_val[:, (t+1)*20:(t+1)*20+30, :]
        
    if epoch % 500 == 0:
        i = random.randint(0, X_train.shape[0]-1)
        X, Y = [], []
        x = X_train[i, :20, :]
        X.append(x)
        X = np.array(X)
        Y_hat = seq.model.predict(X)
        result = np.concatenate((X, Y_hat), axis=1)
        for j in range(1):
            X_in = result[:, -20:, :]
            Y_hat_out = seq.model.predict(X_in)
            result = np.concatenate((result, Y_hat_out), axis=1)   
        Y_hat_decoded = ae.decode_series(result)
        show_images_as_video(Y_hat_decoded[0])
    seq.save_weights(root+"/../models/seq2seq_recursive_v1.h5")
# Out:
# EPOCH 2501
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0386 - val_loss: 201.9769
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6746 - val_loss: 201.5562
# EPOCH 2502
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0349 - val_loss: 201.9923
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6664 - val_loss: 201.6657
# EPOCH 2503
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0348 - val_loss: 202.1348
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6774 - val_loss: 201.6419
# EPOCH 2504
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0382 - val_loss: 202.1415
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.7389 - val_loss: 201.8599
# EPOCH 2505
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0203 - val_loss: 202.1308
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6816 - val_loss: 201.6817
# EPOCH 2506
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0258 - val_loss: 201.9961
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6608 - val_loss: 201.5148
# EPOCH 2507
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0388 - val_loss: 201.9688
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6558 - val_loss: 201.4936
# EPOCH 2508
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0448 - val_loss: 202.0104
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6572 - val_loss: 201.6020
# EPOCH 2509
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0338 - val_loss: 202.0841
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.7015 - val_loss: 201.8635
# EPOCH 2510
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0280 - val_loss: 202.1806
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6708 - val_loss: 201.6490
# EPOCH 2511
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0386 - val_loss: 202.0455
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6521 - val_loss: 201.4381
# EPOCH 2512
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0333 - val_loss: 201.8334
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6616 - val_loss: 201.2850
# EPOCH 2513
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0726 - val_loss: 201.6585
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6815 - val_loss: 201.2212
# EPOCH 2514
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0545 - val_loss: 201.6821
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6971 - val_loss: 201.2959
# EPOCH 2515
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0227 - val_loss: 201.8272
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6718 - val_loss: 201.5335
# EPOCH 2516
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0142 - val_loss: 202.0601
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6943 - val_loss: 201.8237
# EPOCH 2517
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0333 - val_loss: 202.1377
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6795 - val_loss: 201.7512
# EPOCH 2518
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0287 - val_loss: 201.9940
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6706 - val_loss: 201.5143
# EPOCH 2519
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0389 - val_loss: 201.9458
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6666 - val_loss: 201.4617
# EPOCH 2520
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0128 - val_loss: 201.8841
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6816 - val_loss: 201.4716
# EPOCH 2521
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0293 - val_loss: 201.9193
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6694 - val_loss: 201.5202
# EPOCH 2522
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0240 - val_loss: 202.0491
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6611 - val_loss: 201.6039
# EPOCH 2523
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0546 - val_loss: 202.1647
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6826 - val_loss: 201.7003
# EPOCH 2524
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0648 - val_loss: 202.1693
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6665 - val_loss: 201.7773
# EPOCH 2525
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0274 - val_loss: 202.1277
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6734 - val_loss: 201.6024
# EPOCH 2526
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0188 - val_loss: 202.0679
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6671 - val_loss: 201.5360
# EPOCH 2527
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0241 - val_loss: 202.0601
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6564 - val_loss: 201.7430
# EPOCH 2528
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0488 - val_loss: 202.1419
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6604 - val_loss: 201.6595
# EPOCH 2529
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0608 - val_loss: 202.0952
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6681 - val_loss: 201.5089
# EPOCH 2530
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0399 - val_loss: 201.9036
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6613 - val_loss: 201.4503
# EPOCH 2531
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0227 - val_loss: 201.9272
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6790 - val_loss: 201.5694
# EPOCH 2650
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0162 - val_loss: 202.0384
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6764 - val_loss: 201.6304
# EPOCH 2651
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0151 - val_loss: 202.0709
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6736 - val_loss: 201.6042
# EPOCH 2652
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0087 - val_loss: 201.9655
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6977 - val_loss: 201.4945
# EPOCH 2653
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0162 - val_loss: 201.9833
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6712 - val_loss: 201.6451
# EPOCH 2654
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0205 - val_loss: 202.0306
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6895 - val_loss: 201.4950
# EPOCH 2655
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0133 - val_loss: 201.9405
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6953 - val_loss: 201.5800
# EPOCH 2656
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0350 - val_loss: 201.8624
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6763 - val_loss: 201.5274
# EPOCH 2657
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0179 - val_loss: 201.9293
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6519 - val_loss: 201.5997
# EPOCH 2658
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0204 - val_loss: 202.0478
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6544 - val_loss: 201.6332
# EPOCH 2659
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.0275 - val_loss: 202.0447
# (84, 20, 64) (84, 30, 64)
# Train on 84 samples, validate on 24 samples
# Epoch 1/1
# 84/84 [==============================] - 0s 3ms/step - loss: 157.6937 - val_loss: 201.4612

# %%
def produce_videos(train=True, val=False, test=False):
    i = 0
    if train:
        i = random.randint(0, X_train.shape[0]-1)
    elif val:
        i = random.randint(0, X_val.shape[0]-1)
    elif test:
        i = random.randint(0, X_test.shape[0]-1)
    X, Y = [], []
    x, y = None, None
    if train:
        x = X_train[i, :20, :]
        y = X_train[i, 20:50, :]
    elif val:
        x = X_val[i, :20, :]
        y = X_val[i, 20:50, :]
    elif test:
        x = X_test[i, :20, :]
        y = X_test[i, 20:50, :]
    X.append(x)
    X = np.array(X)
    Y.append(y)
    Y = np.array(Y)
    Y_hat = seq.model.predict(X)
    result = np.concatenate((X, Y_hat), axis=1)
    Y_hat_decoded = ae.decode_series(result)
    result = np.concatenate((X, Y), axis=1)
    Y_decoded = ae.decode_series(result)
    return Y_decoded[0], Y_hat_decoded[0]

# %%
Y, Y_hat = produce_videos(test=True)

# %%
compare_images_as_video(Y, Y_hat)

# %%
Y, Y_hat = produce_videos(test=True)

# %%
compare_images_as_video(Y, Y_hat)

# %%
def produce_long_videos(train=True, val=False, test=False):
    i = 0
    if train:
        i = random.randint(0, X_train.shape[0]-1)
    elif val:
        i = random.randint(0, X_val.shape[0]-1)
    elif test:
        i = random.randint(0, X_test.shape[0]-1)
    X, Y = [], []
    x, y = None, None
    if train:
        x = X_train[i, :20, :]
        y = X_train[i, 20:50, :]
    elif val:
        x = X_val[i, :20, :]
        y = X_val[i, 20:50, :]
    elif test:
        x = X_test[i, :20, :]
        y = X_test[i, 20:50, :]
    X.append(x)
    X = np.array(X)
    Y_hat = seq.model.predict(X)
    result = np.concatenate((X, Y_hat), axis=1)
    for j in range(1):
        X_in = result[:, -20:, :]
        Y_hat_out = seq.model.predict(X_in)
        result = np.concatenate((result, Y_hat_out), axis=1)    
    print(result.shape)
    Y_hat_decoded = ae.decode_series(result)
    if train:
        y = X_train[i, :result.shape[1], :]
    elif val:
        y = X_val[i, :result.shape[1], :]
    elif test:
        y = X_test[i, :result.shape[1], :]
    Y.append(y)
    Y = np.array(Y)    
    Y_decoded = ae.decode_series(Y)
    return Y_decoded[0], Y_hat_decoded[0]

# %%
Y_long, Y_hat_long = produce_long_videos(test=True)
# Out:
# (1, 80, 64)

# %%
compare_images_as_video(Y_long, Y_hat_long)
