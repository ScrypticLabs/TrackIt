# %%
# THIS NOTEBOOK TRAINS THE Seq2Seq MODEL WHERE INPUT SEQUENCE LENGTH IS NOT FIXED

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
from data_loader import DataLoader
from utils.visualize import show_images_in_grid, show_images_as_video, show_reconstructions, compare_images_as_video
from cnn import Autoencoder
from utils.build_futures import *
from rnn_one_to_one import Seq2Seq
import random
import matplotlib.pyplot as plt

# %%
root = os.getcwd()

# %%
rnn_data_loader = DataLoader()

# %%
rnn_data_loader.X_train = np.load(root+"/../datasets/train/32/X_train_normalized.npy")
rnn_data_loader.X_val = np.load(root+"/../datasets/val/32/X_val_normalized.npy")
rnn_data_loader.X_test = np.load(root+"/../datasets/test/32/X_test_normalized.npy")

# %%
# LET'S COMPUTE THE EMBEDDINGS FROM THE DATA AND TRAINED AUTOENCODER

# %%
ae = Autoencoder()
ae.build_model(input_dim=(32, 32, 3), latent_dim=(64,))
ae.set_weights(root+"/../models/autoencoder_32_v3.h5")

# %%
X_train = ae.encode_series(rnn_data_loader.X_train)
X_val = ae.encode_series(rnn_data_loader.X_val)
X_test = ae.encode_series(rnn_data_loader.X_test)

# %%
X_train.shape
# Out:
# (160, 100, 64)

# %%
seq = Seq2Seq()
seq.build_model(input_dim=64, output_dim=64)

# %%
# seq.set_weights(root+"/../models/seq2seq_one_to_one_32.h5")

# %%
seq.model.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, None, 64)          0
# _________________________________________________________________
# lstm_2 (LSTM)                [(None, None, 1024), (Non 4460544
# _________________________________________________________________
# dense_8 (Dense)              (None, None, 64)          65600
# =================================================================
# Total params: 4,526,144
# Trainable params: 4,526,144
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = {
    "loss" : [],
    "val_loss" : []
}

# %%
# TRAIN LOOP
for epoch in range(10000):
    print('EPOCH %d' % (epoch))
    hist = seq.train(X_train=X_train[:, 0:X_train.shape[1]-1, :], 
                     Y_train=X_train[:, 1:X_train.shape[1], :], 
                     X_val=X_val[:, 0:X_val.shape[1]-1, :], 
                     Y_val=X_val[:, 1:X_val.shape[1], :], 
                     epochs=1, 
                     batch_size=32
                     )
    history["loss"].append(hist.history["loss"][0])
    history["val_loss"].append(hist.history["val_loss"][0])
    if epoch % 500 == 0:
        i = random.randint(0, X_train.shape[0]-1)
        X, Y = [], []
        x = X_train[i, 0:X_train.shape[1]-1, :]
        X.append(x)
        X = np.array(X)
        y = X_train[i, 1:X_train.shape[1], :]
        Y.append(y)
        Y = np.array(Y)
        Y_hat = seq.model.predict(X)
        Y_decoded = ae.decode_series(Y)
        Y_hat_decoded = ae.decode_series(Y_hat)
        compare_images_as_video(Y_decoded[0], Y_hat_decoded[0])
    seq.save_weights(root+"/../models/seq2seq_one_to_one_32_v3.h5")
# Out:
# EPOCH 4501
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4139 - val_loss: 185.9488
# EPOCH 4502
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4299 - val_loss: 185.9288
# EPOCH 4503
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4434 - val_loss: 185.9538
# EPOCH 4504
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4488 - val_loss: 185.9322
# EPOCH 4505
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4508 - val_loss: 185.9579
# EPOCH 4506
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4473 - val_loss: 185.9411
# EPOCH 4507
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4477 - val_loss: 185.9581
# EPOCH 4508
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 185.9537
# EPOCH 4509
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4617 - val_loss: 185.9507
# EPOCH 4510
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4761 - val_loss: 185.9513
# EPOCH 4511
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4975 - val_loss: 185.9454
# EPOCH 4512
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5116 - val_loss: 185.9111
# EPOCH 4513
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5227 - val_loss: 185.9574
# EPOCH 4514
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5169 - val_loss: 185.8370
# EPOCH 4515
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5038 - val_loss: 185.9877
# EPOCH 4516
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4824 - val_loss: 185.7621
# EPOCH 4517
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4616 - val_loss: 186.0182
# EPOCH 4518
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4456 - val_loss: 185.7181
# EPOCH 4519
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4357 - val_loss: 186.0270
# EPOCH 4520
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4340 - val_loss: 185.7126
# EPOCH 4521
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4399 - val_loss: 186.0044
# EPOCH 4522
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4506 - val_loss: 185.7345
# EPOCH 4523
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4643 - val_loss: 185.9531
# EPOCH 4524
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4736 - val_loss: 185.7751
# EPOCH 4525
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4768 - val_loss: 185.8874
# EPOCH 4526
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4685 - val_loss: 185.8295
# EPOCH 4527
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4543 - val_loss: 185.8298
# EPOCH 4528
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4344 - val_loss: 185.8826
# EPOCH 4529
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4179 - val_loss: 185.7995
# EPOCH 4530
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4042 - val_loss: 185.9146
# EPOCH 4531
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3975 - val_loss: 185.8029
# EPOCH 4532
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3960 - val_loss: 185.9204
# EPOCH 4533
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4025 - val_loss: 185.8274
# EPOCH 4534
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4138 - val_loss: 185.9077
# EPOCH 4535
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4327 - val_loss: 185.8516
# EPOCH 4536
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4514 - val_loss: 185.8885
# EPOCH 4537
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4718 - val_loss: 185.8591
# EPOCH 4538
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4821 - val_loss: 185.8776
# EPOCH 4539
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4867 - val_loss: 185.8430
# EPOCH 4540
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4787 - val_loss: 185.8841
# EPOCH 4541
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4733 - val_loss: 185.8045
# EPOCH 4542
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4682 - val_loss: 185.8955
# EPOCH 4543
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4818 - val_loss: 185.7452
# EPOCH 4544
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4988 - val_loss: 185.9026
# EPOCH 4545
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5332 - val_loss: 185.6617
# EPOCH 4546
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5556 - val_loss: 185.9282
# EPOCH 4547
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5875 - val_loss: 185.5637
# EPOCH 4548
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5961 - val_loss: 185.9744
# EPOCH 4549
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.6230 - val_loss: 185.4769
# EPOCH 4550
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.6326 - val_loss: 185.9961
# EPOCH 4551
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.6748 - val_loss: 185.3787
# EPOCH 4552
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.6896 - val_loss: 185.9960
# EPOCH 4553
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.7248 - val_loss: 185.2156
# EPOCH 4554
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.7020 - val_loss: 186.0264
# EPOCH 4555
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.6908 - val_loss: 185.0551
# EPOCH 4556
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.6378 - val_loss: 186.0501
# EPOCH 4557
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.6188 - val_loss: 185.0326
# EPOCH 4558
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5937 - val_loss: 185.9925
# EPOCH 4559
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5991 - val_loss: 185.1268
# EPOCH 4560
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5984 - val_loss: 185.8953
# EPOCH 4561
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.6081 - val_loss: 185.2061
# EPOCH 4562
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.6025 - val_loss: 185.8448
# EPOCH 4563
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5917 - val_loss: 185.2175
# EPOCH 4564
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5622 - val_loss: 185.8448
# EPOCH 4565
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5306 - val_loss: 185.2028
# EPOCH 4566
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4976 - val_loss: 185.8374
# EPOCH 4567
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4773 - val_loss: 185.2040
# EPOCH 4568
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4633 - val_loss: 185.7976
# EPOCH 4569
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4527 - val_loss: 185.2446
# EPOCH 4570
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4415 - val_loss: 185.7500
# EPOCH 4571
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4277 - val_loss: 185.3227
# EPOCH 4572
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4211 - val_loss: 185.7087
# EPOCH 4573
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4182 - val_loss: 185.4072
# EPOCH 4574
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4286 - val_loss: 185.6750
# EPOCH 4575
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4391 - val_loss: 185.4638
# EPOCH 4576
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4569 - val_loss: 185.6562
# EPOCH 4577
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4635 - val_loss: 185.4944
# EPOCH 4578
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4696 - val_loss: 185.6519
# EPOCH 4579
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4594 - val_loss: 185.5187
# EPOCH 4580
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4523 - val_loss: 185.6548
# EPOCH 4581
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4371 - val_loss: 185.5414
# EPOCH 4582
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4352 - val_loss: 185.6511
# EPOCH 4583
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4321 - val_loss: 185.5533
# EPOCH 4584
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4424 - val_loss: 185.6376
# EPOCH 4585
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4470 - val_loss: 185.5515
# EPOCH 4586
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4567 - val_loss: 185.6216
# EPOCH 4587
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4549 - val_loss: 185.5479
# EPOCH 4588
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4555 - val_loss: 185.6043
# EPOCH 4589
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4490 - val_loss: 185.5576
# EPOCH 4590
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4515 - val_loss: 185.5755
# EPOCH 4591
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4532 - val_loss: 185.5874
# EPOCH 4592
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4666 - val_loss: 185.5269
# EPOCH 4593
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4739 - val_loss: 185.6397
# EPOCH 4594
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4885 - val_loss: 185.4641
# EPOCH 4595
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4875 - val_loss: 185.7077
# EPOCH 4596
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4921 - val_loss: 185.4088
# EPOCH 4597
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4813 - val_loss: 185.7615
# EPOCH 4598
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4820 - val_loss: 185.3878
# EPOCH 4599
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4736 - val_loss: 185.7655
# EPOCH 4600
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4798 - val_loss: 185.4153
# EPOCH 4601
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4768 - val_loss: 185.7203
# EPOCH 4602
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4855 - val_loss: 185.4781
# EPOCH 4603
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4834 - val_loss: 185.6588
# EPOCH 4604
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4903 - val_loss: 185.5411
# EPOCH 4605
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4862 - val_loss: 185.6103
# EPOCH 4606
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4886 - val_loss: 185.5759
# EPOCH 4607
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4784 - val_loss: 185.5823
# EPOCH 4608
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4726 - val_loss: 185.5822
# EPOCH 4609
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4554 - val_loss: 185.5681
# EPOCH 4610
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4440 - val_loss: 185.5788
# EPOCH 4611
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4257 - val_loss: 185.5597
# EPOCH 4612
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4136 - val_loss: 185.5854
# EPOCH 4613
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3965 - val_loss: 185.5542
# EPOCH 4614
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3852 - val_loss: 185.6109
# EPOCH 4615
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3733 - val_loss: 185.5532
# EPOCH 4616
# Train on 160 samples, validate on 20 samples
# Epoch 1/1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-f094a5cc46b5> in <module>
#       7                      Y_val=X_val[:, 1:X_val.shape[1], :],
#       8                      epochs=1,
# ----> 9                      batch_size=32
#      10                      )
#      11     history["loss"].append(hist.history["loss"][0])
#
# ~/TrackIt/src/rnn_one_to_one.py in train(self, X_train, Y_train, X_val, Y_val, epochs, batch_size)
#      74                     batch_size=batch_size,
#      75                     validation_data=(X_val, Y_val),
# ---> 76                     shuffle=False
#      77                     # callbacks=[self.status_callback, self.checkpoint]
#      78                 )
#
# ~/anaconda3/envs/envTF113/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~/anaconda3/envs/envTF113/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/envs/envTF113/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3074
#    3075     fetched = self._callable_fn(*array_vals,
# -> 3076                                 run_metadata=self.run_metadata)
#    3077     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3078     return nest.pack_sequence_as(self._outputs_structure,
#
# ~/anaconda3/envs/envTF113/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# Plot training & validation loss values
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# i = 147
X, Y, Y_hat, i = build_future_from_past_at_a_time(seq_model=seq, ae_model=ae, X=X_train, past_horizon=2, future_horizon=50)
compare_images_as_video(Y, Y_hat)
